# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_palette('pastel')

# %%
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten
from sklearn.metrics import r2_score

# %%
df=pd.read_csv('dataframe.csv',index_col=0)

# %%
df.head()
# Out:
#      id  host_is_superhost  host_has_profile_pic  host_identity_verified  \
# 0  2015                1.0                   1.0                     1.0
# 1  2695                0.0                   1.0                     1.0
# 2  3176                0.0                   1.0                     1.0
# 3  3309                0.0                   1.0                     1.0
# 5  9991                0.0                   1.0                     1.0
#
#    is_location_exact  accommodates  bathrooms  bedrooms  beds  price  \
# 0                  0             3        1.0       1.0   2.0   60.0
# 1                  1             2        1.0       1.0   1.0   17.0
# 2                  1             4        1.0       1.0   2.0   90.0
# 3                  1             2        1.0       1.0   1.0   26.0
# 5                  0             7        2.5       4.0   7.0  180.0
#
#           ...           room_type_Private room  room_type_Entire home/apt  \
# ...

# %%
X=df.drop(['id','price'],axis=1)
y=df['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X, y, test_size=0.1, random_state=42)

# %%
DNN=Sequential()

# %%
DNN.add(Dense(12, activation='relu', input_dim=X.shape[1]))
DNN.add(Dense(12, activation='relu'))
DNN.add(Dense(12, activation='relu'))
DNN.add(Dense(1, activation='linear'))

# %%
DNN.compile(optimizer='adam', loss='mse', metrics=['mse'])
DNN.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_17 (Dense)             (None, 12)                672
# _________________________________________________________________
# dense_18 (Dense)             (None, 12)                156
# _________________________________________________________________
# dense_19 (Dense)             (None, 12)                156
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 13
# ...
# Total params: 997
# Trainable params: 997
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=DNN.fit(X,y,epochs=120,batch_size=128,validation_split=0.2)
# Out:
# Train on 17678 samples, validate on 4420 samples
# Epoch 1/120
# 17678/17678 [==============================] - 0s 25us/step - loss: 921.9617 - mean_squared_error: 921.9617 - val_loss: 1144.9627 - val_mean_squared_error: 1144.9627
# Epoch 2/120
# 17678/17678 [==============================] - 0s 25us/step - loss: 880.0772 - mean_squared_error: 880.0772 - val_loss: 1111.9153 - val_mean_squared_error: 1111.9153
# Epoch 3/120
# 17678/17678 [==============================] - 0s 25us/step - loss: 847.7629 - mean_squared_error: 847.7629 - val_loss: 1090.1141 - val_mean_squared_error: 1090.1141
# Epoch 4/120
# 17678/17678 [==============================] - 1s 31us/step - loss: 823.9958 - mean_squared_error: 823.9958 - val_loss: 1057.7618 - val_mean_squared_error: 1057.7618
# Epoch 5/120
# 17678/17678 [==============================] - 0s 25us/step - loss: 803.1557 - mean_squared_error: 803.1557 - val_loss: 1047.7948 - val_mean_squared_error: 1047.7948
# Epoch 6/120
# ...

# %%
print(history.history.keys())
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
# Out:
# dict_keys(['val_loss', 'val_mean_squared_error', 'loss', 'mean_squared_error'])

# %%
print(r2_score(y_train,DNN.predict(X_train)))
print(r2_score(y_test,DNN.predict(X_test)))
# Out:
# 0.520419748557809
# 0.5190928254368377
